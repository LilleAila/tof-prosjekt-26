# %%
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv("data_010.csv")
df2 = pd.read_csv("data_011.csv")

# %%
df1.plot(x="Timestamp", y="Temperature (C)")
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df1.plot(x="Timestamp", y="Humidity (%)")
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df2.plot(x="Timestamp", y="Temperature (C)")
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df2.plot(x="Timestamp", y="Humidity (%)")
# Out:
# <Axes: xlabel='Timestamp'>
