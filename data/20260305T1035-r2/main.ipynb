# %%
import pandas as pd

df = pd.read_csv("data.csv")
df
# Out:
#       Timestamp  Temperature (C)  Humidity (%)     Sound  Light
# 0          4551            22.09         19.53      0.00  625.0
# 1          7551            22.35         19.59  31379.09  631.0
# 2         10551            22.35         19.67  22004.61  626.0
# 3         13551            22.34         19.62  39598.80  632.0
# 4         16551            22.34         19.54  29176.10  629.0
# ...         ...              ...           ...       ...    ...
# 3512   10540551            21.49         27.35  10729.98  885.0
# 3513   10543551            21.50         27.35  10729.98  882.0
# 3514   10546551            21.49         27.35  10729.98  878.0
# 3515   10549551            21.49         27.36  10729.98  886.0
# 3516   10552551            21.49         27.37  10729.98  875.0
#
# [3517 rows x 5 columns]

# %%
df["Sound"].plot()
# Out:
# <Axes: >

# %%
df["Temperature (C)"].plot()
# Out:
# <Axes: >

# %%
df["Humidity (%)"].plot()
# Out:
# <Axes: >

# %%
df["Light"].plot()
# Out:
# <Axes: >
