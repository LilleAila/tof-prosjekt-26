# %%
import pandas as pd

# %%
df = pd.read_csv("a2-data0.csv")
ts = df["Timestamp"]
ts.plot()
ts.index[ts < ts.shift(1)] + 2
# Out:
# Index([], dtype='int64')

# %%
# Duration: 2m early start, 2x it time, 10m friminutt, halv neste friminutt
d = (2+60+10+60+5)*60*1000
print(d)
df.index[df["Timestamp"] >= d][0] + 2
# Out:
# 8220000
# np.int64(2741)
