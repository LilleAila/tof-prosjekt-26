# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#       Timestamp  Temperature (C)  Humidity (%)     Sound  Light
# 0          4085            22.19         29.26      0.00  614.0
# 1          7085            22.45         28.95  43645.01  642.0
# 2         10085            22.45         28.85  24461.71  644.0
# 3         13085            22.45         28.82  32673.80  646.0
# 4         16085            22.45         28.86  43991.20  646.0
# ...         ...              ...           ...       ...    ...
# 3251    9757085            20.46         36.10   6820.98  422.0
# 3252    9760085            20.47         36.08   6820.98  421.0
# 3253    9763085            20.46         36.06   6820.98  423.0
# 3254    9766085            20.47         36.10   6820.98  417.0
# 3255    9769085            20.46         36.12   6820.98  195.0
#
# [3256 rows x 5 columns]

# %%
df["Sound"].plot()
# Out:
# <Axes: >

# %%
df["Light"].plot()
# Out:
# <Axes: >

# %%
df["Humidity (%)"].plot()
# Out:
# <Axes: >

# %%
df["Temperature (C)"].plot()
# Out:
# <Axes: >
